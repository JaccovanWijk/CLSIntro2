# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
import random
import pandas as pd
from scipy.fft import fft, fftfreq
from scipy.optimize import curve_fit
import networkx as nx
import ndlib.models.epidemics as ep
import ndlib.models.ModelConfig as mc

# %% [markdown]
# # Functions and Definitions

# %%
def ode_demo(y,t,b,g,m):
    """
    Differential equation of a SIR model with equal birth and deathrate.
    
    Arguments:
    y -- vector of s, i and r
    t -- time index (days)
    b -- beta parameter (infectiousness)
    g -- gamma parameter (recovery rate)
    m -- mu parameter (birth and deathrate)
    """
    s,i,r = y
    dsdt = m - b * s * i - m * s
    didt = b * s * i - g * i - m * i
    drdt = g * i - m * r
    
    return dsdt, didt, drdt


def SIR_Events(p):
    """
    Returns the event corrisponding to the p value.
    
    Arguments:
    p -- number of event (integer)
    """
    # Death S
    if p == 0:
        # S, I, R
        return 0,0,0
    
    # Infection
    elif p == 1:
        # S, I, R
        return -1,1,0
        
    # Death I
    elif p == 2:
        # S, I, R
        return 1,-1,0
    
    # Recovered
    elif p == 3:
        # S, I, R
        return 0,-1,1
    
    # Death R
    elif p == 4:
        # S, I, R
        return 1,0,-1
        
    # Import
    elif p == 5:
        # S, I, R
        return -1,1,0
    
        
def SIR_Demo(n, max_t, beta, gamma, mu):
    """
    Stochastic event-driven SIR model with demography.
    
    Arguments:
    n -- population size
    max_t -- stopping time
    beta -- beta parameter (infectiousness)
    gamma -- gamma parameter (recovery rate)
    mu -- mu parameter (birth and deathrate)
    """
    # Set starting values
    S = [0.99*n]
    I = [0.01*n]
    R = [0]
    t = [0]
    current_t = 0
    
    while t[-1] < max_t:
        # Set rates and calculate rate sum
        rates = [mu * S[-1], beta * S[-1] * I[-1] / n,  # rate(S)
                mu * I[-1], gamma * I[-1],  # rate(I)
                mu * R[-1]]  # rate(R)
        rates_sum = sum(rates)
        
        # Get first time step
        current_t += -1*np.log(np.random.random()) / rates_sum
        
        # Calculate all events for time steps
        dS, dI, dR, de = 0, 0, 0, 0
        while current_t < max_t * 0.001:  
            # Get the event
            rand = np.random.random()
            p = 0
            for i in range(len(rates)):
                if rand * rates_sum < sum(rates[:i+1]):
                    p = i
                    break
            
            # Get changes of event
            temp_dS, temp_dI, temp_dR = SIR_Events(p)
            dS += temp_dS
            dI += temp_dI
            dR += temp_dR
            current_t += -1*np.log(np.random.random()) / rates_sum
            
            # Set rates
            rates = [mu * (S[-1] + dS), beta * (S[-1] + dS) * (I[-1] + dI) / n,  # rate(S)
                    mu * (I[-1] + dI), gamma * (I[-1] + dI),  # rate(I)
                    mu * (R[-1] + dR)]  # rate(R)
            rates_sum = sum(rates)
        
        # Add new 
        t.append(t[-1] + current_t)
        current_t = 0
        S.append(S[-1] + dS)
        I.append(I[-1] + dI)
        R.append(R[-1] + dR)

    return S, I, R

def SIR_Import(n, max_t, beta, gamma, mu, epsilon):
    """
    Stochastic event-driven SIR model with demography and imports.
    
    Arguments:
    n -- population size
    max_t -- stopping time
    beta -- beta parameter (infectiousness)
    gamma -- gamma parameter (recovery rate)
    mu -- mu parameter (birth and deathrate)
    epsilon -- epsilon parameter (import rate)
    """
    # Set base variables
    S = [round(0.99*n)]
    I = [round(0.01*n)]
    R = [0]
    t = [0]
    extinctions = 0
    current_t = 0

    while t[-1] < max_t:
        # Set rates
        rates = [mu * S[-1], beta * S[-1] * I[-1] / n,  # rate(S)
                mu * I[-1], gamma * I[-1],  # rate(I)
                mu * R[-1],  # rate(R)
                epsilon * S[-1]] # Import
        rates_sum = sum(rates)
        
        current_t += -1*np.log(np.random.random()) / rates_sum
        
        # Calculate all events for 100 time steps
        dS, dI, dR, de = 0, 0, 0, 0
        while current_t < max_t * 0.001:
            # Get the event
            rand = np.random.random()
            p = 0
            for i in range(len(rates)):
                if rand * rates_sum < sum(rates[:i+1]):
                    p = i
                    break
            
            # Get changes of event
            temp_dS, temp_dI, temp_dR = SIR_Events(p)
            dS += temp_dS
            dI += temp_dI
            dR += temp_dR
            current_t += -1*np.log(np.random.random()) / rates_sum
            
            # Set rates
            rates = [mu * (S[-1] + dS), beta * (S[-1] + dS) * (I[-1] + dI) / n,  # rate(S)
                    mu * (I[-1] + dI), gamma * (I[-1] + dI),  # rate(I)
                    mu * (R[-1] + dR),
                    epsilon * (S[-1] + dS)]  # rate(R)
            rates_sum = sum(rates)
            
        # Add new 
        t.append(t[-1] + current_t)
        current_t = 0
        S.append(S[-1] + dS)
        I.append(I[-1] + dI)
        R.append(R[-1] + dR)
        
        # Check if there is an extinction
        if I[-1] == 0 and I[-2] != 0:
            extinctions += 1

    return S, I, R, extinctions

# %% [markdown]
# # Problem 1: Stochastic Event-Driven SIR Model

# %% [markdown]
# ### Hallmark: Variability

# %%
"""
Four seperate simulations of the event-driven SIR model in epidemic state.
"""
# Set base variables
beta = 1.0
gamma = 0.2
mu = 0.01
population = 100
max_t = 200
epsilon = 5.5 * 10 ** -5 * np.sqrt(population) 

# Simulate stochastic model 4 times
s1, i1, r1, e = SIR_Import(population, max_t, beta, gamma, mu, epsilon)
t1 = np.linspace(0,max_t,len(s1))
s2, i2, r2, e = SIR_Import(population, max_t, beta, gamma, mu, epsilon)
t2 = np.linspace(0,max_t,len(s2))
s3, i3, r3, e = SIR_Import(population, max_t, beta, gamma, mu, epsilon)
t3 = np.linspace(0,max_t,len(s3))
s4, i4, r4, e = SIR_Import(population, max_t, beta, gamma, mu, epsilon)
t4 = np.linspace(0,max_t,len(s4))
s = [s1, s2, s3, s4]
i = [i1, i2, i3, i4]
r = [r1, r2, r3, r4]
t = [t1, t2, t3, t4]

# Simulate deterministic model
time = np.linspace(0, max_t, len(s[0]))
y0 = 0.99, 0.01, 0
integrated = odeint(ode_demo, y0, time, args=(beta, gamma, mu))
s_ode, i_ode, r_ode = integrated.T

# Create subplots
f, ax = plt.subplots(2,2)
index = 0
for row in ax:
    for col in row:
        # Plot deterministic simulation
        col.plot(time, s_ode*population, color='b', linestyle='--')
        col.plot(time, i_ode*population, color='r', linestyle='--')
        col.plot(time, r_ode*population, color='g', linestyle='--')
        # Plot a stochastic simulation
        col.plot(t[index], s[index], color='b')
        col.plot(t[index], i[index], color='r')
        col.plot(t[index], r[index], color='g')
        
        # Set axis layout
        if index < 2:
            col.tick_params(axis='x', which='both', labelbottom=False)
        if index % 2 != 0:
            col.tick_params(axis='y', which='both', labelleft=False)
            
        index += 1

# Make plot
f.text(0.04, 0.5, 'number of people', va='center', rotation='vertical', fontsize=15)
f.text(0.5, 0.02, 'time', ha='center', fontsize=15)
plt.subplots_adjust(wspace=0.05, hspace=0.1)
# plt.savefig("figs/variability_import_epi", dpi=400)        
plt.show()

# %%
"""
Four seperate simulations of the event-driven SIR model in non-epidemic state.
"""
# Set base variables
beta = 1.0
gamma = 1.0
mu = 0.01
population = 100
max_t = 200
epsilon = 5.5 * 10 ** -5 * np.sqrt(population) 

# Simulate stochastic model 4 times
s1, i1, r1, e = SIR_Import(population, max_t, beta, gamma, mu, epsilon)
t1 = np.linspace(0,max_t,len(s1))
s2, i2, r2, e = SIR_Import(population, max_t, beta, gamma, mu, epsilon)
t2 = np.linspace(0,max_t,len(s2))
s3, i3, r3, e = SIR_Import(population, max_t, beta, gamma, mu, epsilon)
t3 = np.linspace(0,max_t,len(s3))
s4, i4, r4, e = SIR_Import(population, max_t, beta, gamma, mu, epsilon)
t4 = np.linspace(0,max_t,len(s4))
s = [s1, s2, s3, s4]
i = [i1, i2, i3, i4]
r = [r1, r2, r3, r4]
t = [t1, t2, t3, t4]

# Simulate deterministic model
time = np.linspace(0, max_t, len(s[0]))
y0 = 0.99, 0.01, 0
integrated = odeint(ode_demo, y0, time, args=(beta, gamma, mu))
s_ode, i_ode, r_ode = integrated.T

# Create subplots
f, ax = plt.subplots(2,2)
index = 0
for row in ax:
    for col in row:
        # Plot deterministic simulation
        col.plot(time, s_ode*population, color='b', linestyle='--')
        col.plot(time, i_ode*population, color='r', linestyle='--')
        col.plot(time, r_ode*population, color='g', linestyle='--')
        # Plot a stochastic simulation
        col.plot(t[index], s[index], color='b')
        col.plot(t[index], i[index], color='r')
        col.plot(t[index], r[index], color='g')
        
        # Set axis layout
        if index < 2:
            col.tick_params(axis='x', which='both', labelbottom=False)
        if index % 2 != 0:
            col.tick_params(axis='y', which='both', labelleft=False)
            
        index += 1
        
# Make plot
plt.subplots_adjust(wspace=0.05, hspace=0.1)
f.text(0.04, 0.5, 'number of people', va='center', rotation='vertical', fontsize=15)
f.text(0.5, 0.02, 'time', ha='center', fontsize=15)
# plt.savefig("figs/variability_import_nonepi", dpi=400)        
plt.show()

# %% [markdown]
# ### Hallmark: necative (co)-variances

# %%
"""
1000 seperate simulations of the event-driven SIR model in epidemic state and
calculating the co-variances between S and I.
"""
# Set base variables
beta = 2
gamma = 0.5
mu = 0.1
population = 1000
max_t = 60
epsilon = 5.5 * 10 ** (-5) * np.sqrt(population)
covlist= []
noiselist = []

# Simulate stochastic model 1000 times
for i in range(1000):
    S, I, R, Ext = SIR_Import(population, max_t, beta, gamma, mu, epsilon)
    T = np.linspace(0,max_t,len(S))
    
    # Calculate co-variance
    cov = np.cov(S, I)[0, 1]
    covlist.append(cov)
    noise = np.std(S)
    noiselist.append(noise)


# Calculate fit through data points
m, b = np.polyfit(noiselist, covlist, 1) 

x = np.sort(np.array(noiselist))

# Make plot
plt.figure()
plt.plot(noiselist, covlist, '.')
plt.plot(x, m*x+b)
plt.yscale('symlog', linthresh=0.01)
plt.xlabel('variance of noise [std(S)]', fontsize=15)
plt.ylabel('covariance between S and I', fontsize=15)
# plt.savefig("figs/covariance", dpi=400)
plt.show()

# %% [markdown]
# ### Hallmark: Increased transcients

# %%
"""
A simulations of the event-driven SIR model in epidemic state compared to the
equilibria of the deterministic models.
"""
# Set base variables
beta = 1
gamma = 0.5
mu = 0.05
population = 1000
max_t = 400
epsilon = 5.5 * 10 ** -5 * np.sqrt(population)

# Do a stochastic simulation
s, i, r, e = SIR_Import(population, max_t, beta, gamma, mu, epsilon)
t = np.linspace(0,max_t,len(s))

# Calculate deterministic equilibria
R0 = beta/(gamma+mu)
Seq = 1/R0
Ieq = (gamma/beta )* (R0-1)
Req = 1 - Seq - Ieq

# Make plots
plt.figure()
plt.axhline(y=Seq*population, color='b', linestyle='--', label='S equilibrium')
plt.axhline(y=Req*population, color='r', linestyle='--', label='I equilibrium')
plt.axhline(y=Ieq*population, color='g', linestyle='--', label='R equilibrium')
plt.xlim([0, max_t])
plt.plot(t, s, color='b', label='S')
plt.plot(t, i, color='r', label='I')
plt.plot(t, r, color='g', label='R')
plt.legend(ncol=2)
plt.xlabel('time', fontsize=15)
plt.ylabel('number of people', fontsize=15)
# plt.savefig("figs/transcients", dpi=400)
plt.show()

# %% [markdown]
# ### Hallmark: Stochastic Resonance

# %%
"""
A simulation of the event-driven model and the deterministic model where
each group of individuals is compared.
"""
# Set base variables
beta = 9
gamma = 3
mu = 3/50
population = 100
max_t = 401
epsilon = 5.5 * 10 ** -5 * np.sqrt(population)

# Simulate deterministic model
time = np.linspace(0, max_t, max_t*2)
y0 = 0.99, 0.01, 0
integrated = odeint(ode_demo, y0, time, args=(beta, gamma, mu))
s_ode, i_ode, r_ode = integrated.T
s_ode *= population
i_ode *= population
r_ode *= population

# Simulate stochastic model
s, i, r, e = SIR_Import(population, max_t, beta, gamma, mu, epsilon)
t = np.linspace(0,max_t,len(s))

# Plot susceptible, infected and recovered in sepeterate subplots
f, (ax1, ax2, ax3) = plt.subplots(3,1)
ax1.plot(time, s_ode, '--', color='b')
ax1.plot(t, s, color='b')
ax1.set_xlim(([-5, max_t + 5]))
ax1.tick_params(axis='x', which='both', labelbottom=False)
ax1.set_ylim([-5, 105])

ax2.plot(time, i_ode, '--', color='r')
ax2.plot(t, i, color='r')
ax2.set_xlim(([-5, max_t + 5]))
ax2.tick_params(axis='x', which='both', labelbottom=False)
ax2.set_ylim([-5, 105])

ax3.plot(time, r_ode, '--', color='g')
ax3.plot(t, r, color='g')
ax3.set_xlim(([-5, max_t + 5]))
ax3.set_ylim([-5, 105])

f.text(0.02, 0.5, 'number of people', va='center', rotation='vertical', fontsize=15)
f.text(0.5, 0.02, 'time', ha='center', fontsize=15)
# plt.savefig("figs/resonance", dpi=400)
plt.show()

# %% [markdown]
# ### Hallmark: Extinctions

# %%
"""
Multiple simulations of the stochastic event-driven model with different
population sizes
"""
def fit_function(x, a, b, c):
    return a*np.exp(-b*x)+c

# Set base variables
beta = 1.0
gamma = 0.5
mu = 0.01
population = np.linspace(500, 3000, 26)
max_t = 1000
ext_list_mean = []

# Take mean of 5 simulations for every population size
for pop in population:
    ext_list = []
    for i in range(5):
        epsilon = 5.5 * 10 ** (-5) * np.sqrt(pop)
        S, I, R, Ext = SIR_Import(pop, max_t, beta, gamma, mu, epsilon)
        ext_list.append(Ext)
    ext_list_mean.append(np.mean(ext_list))

# Generate fit for data
a_fit, b_fit, c_fit = curve_fit(fit_function, np.arange(0,len(population)), ext_list_mean)[0]
fitted = fit_function(np.arange(0,len(population)), a_fit, b_fit, c_fit)

# Make plot
plt.figure()
plt.plot(population, ext_list_mean, '.')
plt.plot(population, fitted)
plt.xlabel("population size", fontsize=15)
plt.ylabel("mean number of extinctions", fontsize=15)
# plt.savefig("figs/extinctions", dpi=400)
plt.show()
# Out:
# <ipython-input-5-b256b2168dfd>:6: RuntimeWarning: overflow encountered in exp
#   return a*np.exp(-b*x)+c

# %% [markdown]
# # Problem 2.1: Metapopulations
#
#
# ### Functions and Definitions

# %%
def SIR_Events(p):
    """
    Returns the event corrisponding to the p value.
    
    Arguments:
    p -- number of event (integer)
    """
    # Infection
    if p == 0:
        # S, I, R
        return -1,1,0
    
    # Recovered
    elif p == 1:
        # S, I, R
        return 0,-1,1

def get_rates(S, I, R, t, subpopulations, beta, gamma, rho):
    """
    Calculate the rates of event-driven model with sub-populations.
    
    Arguments:
    S -- number of susceptible individuals
    I -- number of infected individuals
    R -- number of recovered individuals
    t -- time steps
    subpopulations -- number of sub-populations
    beta -- beta parameter (infectiousness)
    gamma -- gamma parameter (recovery rate)
    rho -- rho parameter (strength of influence)
    """
    rates = []
    for i in range(subpopulations):
        rate = 0
        for j in range(subpopulations):
            rate += rho[i][j] * I[j][-1] / population
        rates.append([beta * rate * S[i][-1], gamma * I[i][-1]])
    rates_sum = 0
    for rate in rates:
        rates_sum += sum(rate)    
    return rates, rates_sum

def get_event(rates, rates_sum):
    """
    Pick random event using the rates of each event.
    
    Arguments:
    rates -- list of different rates for sub-populations
    rates_sum -- sum of all rates
    """
    # Set base variables
    rand = np.random.random()
    p = 0
    sub_event = 0
    all_rates = [x for subrates in rates for x in subrates]
    
    # Get rate and subpopulation of event
    for i in range(len(all_rates)):
        if rand * rates_sum <= sum(all_rates[:i+1]):
            p = i % 2
            sub_event = np.floor(i / len(rates[0])) 
            return p, int(sub_event)
    

def SIR_sub(n, max_t, beta, gamma, rho):
    """
    Stochastic event-driven SIR model with sub-populations.
    
    Arguments:
    n -- population size
    max_t -- stopping time
    beta -- beta parameter (infectiousness)
    gamma -- gamma parameter (recovery rate)
    rho -- rho parameter (strength of influence)
    """
    # Set base variables
    subpopulations = len(rho)
    S = [[n] for i in range(subpopulations)]
    S[0] = [round(0.99*n)]
    I = [[0] for i in range(subpopulations)]
    I[0] = [round(0.01*n)]
    R = [[0] for i in range(subpopulations)]
    t = [0]
    current_t = 0
    
    while t[-1] < max_t:
        # Set rates
        rates, rates_sum = get_rates(S, I, R, t, subpopulations, beta, gamma, rho)        
        if rates_sum == 0:
            break
        current_t += -1*np.log(np.random.random()) / rates_sum

        # Calculate all events for 100 time steps
        dS, dI, dR = [0 for i in range(subpopulations)], [0 for i in range(subpopulations)], [0 for i in range(subpopulations)]
        while current_t < max_t * 0.01:
            # Get the event
            p, sub = get_event(rates, rates_sum)
            
            # Get changes of event and apply to correct subpopulation
            temp_dS, temp_dI, temp_dR = SIR_Events(p)      
            dS[sub] += temp_dS
            dI[sub] += temp_dI
            dR[sub] += temp_dR
            
            if rates_sum == 0:
                break
            current_t += -1*np.log(np.random.random()) / rates_sum
            
            # Set rates
            rates, rates_sum = get_rates([[S[i][-1] + dS[i]] for i in range(len(S))], # temp S + dS
                                         [[I[i][-1] + dI[i]] for i in range(len(I))], # temp I + dI
                                         [[R[i][-1] + dR[i]] for i in range(len(R))], # temp R + dR
                                         t, subpopulations, beta, gamma, rho)
            
        # Add new 
        t.append(t[-1] + current_t)
        current_t = 0
        for i in range(len(S)):
            S[i].append(S[i][-1] + dS[i])
            I[i].append(I[i][-1] + dI[i])
            R[i].append(R[i][-1] + dR[i])
            

    return S, I, R

# %% [markdown]
# ### Two Sub-Populations

# %%
"""
Simulation of stochastic event-driven model with two sub-populations in 
epidemic state.
"""
# Set base variables
beta = 1.0
gamma = 0.2
rho = [[1, 0.01], [0.01, 1]]
population = 1000
max_t = 30

# Do a stochastic event-driven simulation
s, i, r = SIR_sub(population, max_t, beta, gamma, rho)
t = np.linspace(0,max_t,len(s[0]))

# Set colors
blue_colors = ['b', 'deepskyblue']
red_colors = ['r', 'lightcoral']
green_colors = ['g', 'yellowgreen']

# Plot two sub-populations
plt.figure()
for index in range(len(s)):
    plt.plot(t, s[index], color=blue_colors[index], label=f"s {index}")
    plt.plot(t, i[index], color=red_colors[index], label=f"i {index}")
    plt.plot(t, r[index], color=green_colors[index], label=f"r {index}")

# Make plot
plt.legend()    
plt.xlabel("time", fontsize=15)
plt.ylabel("number of people", fontsize=15)
# plt.savefig("figs/two_subpops_epi", dpi=400)
plt.show()

# %%
"""
Simulation of stochastic event-driven model with two sub-populations in non-
epidemic state.
"""
# Set base variables
beta = 1.0
gamma = 1.0
rho = [[1, 0.1], [0.1, 1]]
population = 1000
max_t = 60

# Do a stochastic event-driven simulation
s, i, r = SIR_sub(population, max_t, beta, gamma, rho)
t = np.linspace(0,max_t,len(s[0]))

# Set colors
blue_colors = ['b', 'deepskyblue']
red_colors = ['r', 'lightcoral']
green_colors = ['g', 'yellowgreen']

# Plot two sub-populations
plt.figure()
for index in range(len(s)):
    plt.plot(t, s[index], color=blue_colors[index], label=f"s {index}")
    plt.plot(t, i[index], color=red_colors[index], label=f"i {index}")
    plt.plot(t, r[index], color=green_colors[index], label=f"r {index}")

# Make plot
plt.legend()
plt.xlabel("time", fontsize=15)
plt.ylabel("number of people", fontsize=15)
# plt.savefig("figs/two_subpops_non", dpi=400)
plt.show()

# %% [markdown]
# ### Four Sub-Populations

# %%
"""
Simulation of stochastic event-driven model with four sub-populations in 
epidemic state.
"""
# Set base variables
beta = 1.0
gamma = 0.2
rho = [[1, 0.001, 0.0, 0.0], [0.01, 1, 0.0005, 0.0], [0.0, 0.0005, 1, 0.0005], [0.0, 0.0, 0.0005, 1]]
population = 1000
max_t = 60

# Do stochastic 4 times
s1, i1, r1 = SIR_sub(population, max_t, beta, gamma, rho)
t1 = np.linspace(0,max_t,len(s1[0]))
s2, i2, r2 = SIR_sub(population, max_t, beta, gamma, rho)
t2 = np.linspace(0,max_t,len(s2[0]))
s3, i3, r3 = SIR_sub(population, max_t, beta, gamma, rho)
t3 = np.linspace(0,max_t,len(s3[0]))
s4, i4, r4 = SIR_sub(population, max_t, beta, gamma, rho)
t4 = np.linspace(0,max_t,len(s4[0]))
s = [s1, s2, s3, s4]
i = [i1, i2, i3, i4]
r = [r1, r2, r3, r4]
t = [t1, t2, t3, t4]

# Create subplot
f, ax = plt.subplots(2,2)
index = 0
for row in ax:
    for col in row:
        # Plot infected of simulation
        for j in range(len(i[index])):
            col.plot(t[index], i[index][j])
        
        if index < 2:
            col.tick_params(axis='x', which='both', labelbottom=False)
        if index % 2 != 0:
            col.tick_params(axis='y', which='both', labelleft=False)
            
        index += 1
        
# Make plot
plt.subplots_adjust(wspace=0.05, hspace=0.1)
f.text(0.04, 0.5, 'number of people', va='center', rotation='vertical', fontsize=15)
f.text(0.5, 0.02, 'time', ha='center', fontsize=15)
# plt.savefig("figs/subpopulations_infected", dpi=400)        
plt.show()

# %% [markdown]
# # Problem 2.2: Networks

# %% [markdown]
# ### Functions and Definitions

# %%
def erdos(pop_size, p, tmax, ini):
    """
    Explain a bit
    
    Arguments:
    pop_size -- population size
    p -- 
    tmax -- 
    ini -- 
    """
    # 
    g = nx.erdos_renyi_graph(pop_size, p)
    maxlist = []
    model = ep.SIRModel(g)

    # 
    if ini == 'hub':
        degreelist = [x for x in np.arange(0, pop_size, 1)]
        degrees = g.degree()
        for i in degrees:
            maxlist.append(i[1])
        new_list = sorted(zip(maxlist, degreelist), reverse=True)[:3]
    elif ini == 'random':
        new_list = [random.randint(0, pop_size), random.randint(0, pop_size), random.randint(0, pop_size)]

    # 
    config = mc.Configuration()
    config.add_model_parameter('beta', 0.001)
    config.add_model_parameter('gamma', 0.01)

    # 
    if ini == 'hub':
        infected_nodes = [new_list[x][1] for x in np.arange(0,3)]
        config.add_model_initial_configuration("Infected", infected_nodes)
    elif ini == 'random':
        infected_nodes = new_list
        config.add_model_initial_configuration("Infected", infected_nodes)
    else:
        config.add_model_parameter("fraction_infected", 0.05)

    model.set_initial_status(config)

    if ini == "vaccinhub":
        count = 0
        I = []
        while count < tmax:
            vaccinlist = []
            iterations = model.iteration()
            dict = iterations
            I.append(dict['node_count'][1])
            times = 0
            while times < 3:
                degrees = g.degree()
                for i in degrees:
                    vaccinlist.append(i[1])
                maxdegree = vaccinlist.index(max(vaccinlist))
                try:
                    for edge in list(g.edges(maxdegree)):
                        g.remove_edge(edge[0], edge[1])
                except:
                    continue
                times += 1
            count+=1
        return g, I

    elif ini == "vaccinrandom":
        count = 0
        I = []
        while count < tmax:
            iterations = model.iteration()
            dict = iterations
            I.append(dict['node_count'][1])
            times = 0
            while times < 3:
                maxdegree = random.randint(0, pop_size)
                try:
                    for edge in list(g.edges(maxdegree)):
                        g.remove_edge(edge[0], edge[1])
                except:
                    continue
                times +=1
            count+=1
        return g, I

    else:
        iterations = model.iteration_bunch(tmax)
        return g, iterations


def watts(pop_size, k, tmax, ini):
    """
    
    """
    g = nx.watts_strogatz_graph(pop_size, k, 0.25, seed=None)
    maxlist = []
    model = ep.SIRModel(g)

    if ini == 'hub':
        degreelist = [x for x in np.arange(0, pop_size, 1)]
        degrees = g.degree()
        for i in degrees:
            maxlist.append(i[1])
        new_list = sorted(zip(maxlist, degreelist), reverse=True)[:3]
    elif ini == 'random':
        new_list = [random.randint(0, pop_size), random.randint(0, pop_size), random.randint(0, pop_size)]

    config = mc.Configuration()
    config.add_model_parameter('beta', 0.001)
    config.add_model_parameter('gamma', 0.01)
    if ini == 'hub':
        infected_nodes = [new_list[x][1] for x in np.arange(0,3)]
        config.add_model_initial_configuration("Infected", infected_nodes)
    elif ini == 'random':
        infected_nodes = new_list
        config.add_model_initial_configuration("Infected", infected_nodes)
    else:
        config.add_model_parameter("fraction_infected", 0.05)

    model.set_initial_status(config)

    if ini == "vaccinhub":
        count = 0
        I = []
        while count < tmax:
            vaccinlist = []
            iterations = model.iteration()
            dict = iterations
            I.append(dict['node_count'][1])
            times = 0
            while times < 3:
                degrees = g.degree()
                for i in degrees:
                    vaccinlist.append(i[1])
                maxdegree = vaccinlist.index(max(vaccinlist))
                try:
                    for edge in list(g.edges(maxdegree)):
                        g.remove_edge(edge[0], edge[1])
                except:
                    continue
                times += 1
            count+=1
        return g, I

    elif ini == "vaccinrandom":
        count = 0
        I = []
        while count < tmax:
            iterations = model.iteration()
            dict = iterations
            I.append(dict['node_count'][1])
            times = 0
            while times < 3:
                maxdegree = random.randint(0, pop_size)
                try:
                    for edge in list(g.edges(maxdegree)):
                        g.remove_edge(edge[0], edge[1])
                except:
                    continue
                times += 1
            count+=1
        return g, I

    else:
        iterations = model.iteration_bunch(tmax)
        return g, iterations


def barabasi(pop_size, m, tmax, ini):
    """
    
    """
    g = nx.barabasi_albert_graph(pop_size, m)
    maxlist = []
    model = ep.SIRModel(g)

    if ini == 'hub':
        degreelist = [x for x in np.arange(0, pop_size, 1)]
        degrees = g.degree()
        for i in degrees:
            maxlist.append(i[1])
        new_list = sorted(zip(maxlist, degreelist), reverse=True)[:3]
    elif ini == 'random':
        new_list = [random.randint(0, pop_size), random.randint(0, pop_size), random.randint(0, pop_size)]

    config = mc.Configuration()
    config.add_model_parameter('beta', 0.001)
    config.add_model_parameter('gamma', 0.01)
    if ini == 'hub':
        infected_nodes = [new_list[x][1] for x in np.arange(0,3)]
        config.add_model_initial_configuration("Infected", infected_nodes)
    elif ini == 'random':
        infected_nodes = new_list
        config.add_model_initial_configuration("Infected", infected_nodes)
    else:
        config.add_model_parameter("fraction_infected", 0.05)

    model.set_initial_status(config)

    if ini == "vaccinhub":
        count = 0
        I = []
        while count < tmax:
            vaccinlist = []
            iterations = model.iteration()
            dict = iterations
            I.append(dict['node_count'][1])
            times = 0
            while times < 3:
                degrees = g.degree()
                for i in degrees:
                    vaccinlist.append(i[1])
                maxdegree = vaccinlist.index(max(vaccinlist))
                try:
                    for edge in list(g.edges(maxdegree)):
                        g.remove_edge(edge[0], edge[1])
                except:
                    continue
                times += 1
            count+=1
        return g, I

    elif ini == "vaccinrandom":
        count = 0
        I = []
        while count < tmax:
            iterations = model.iteration()
            dict = iterations
            I.append(dict['node_count'][1])
            times = 0
            while times < 3:
                maxdegree = random.randint(0, pop_size)
                try:
                    for edge in list(g.edges(maxdegree)):
                        g.remove_edge(edge[0], edge[1])
                except:
                    continue
                times += 1
            count+=1
        return g, I

    else:
        iterations = model.iteration_bunch(tmax)
        return g, iterations

# %% [markdown]
# ### Measure Spread of Disease

# %%
"""

"""
# Set base variables
prob = np.arange(0, 0.07, 0.0025)
R_list_erdos = []
k_avg_erdos = []
pop_size = 2500
tmax = 1000

# 
for p in prob:
    g, iterations = erdos(pop_size, p, tmax, 'nope')
    degrees = g.degree()
    sum_edges = 0
    for i in degrees:
        sum_edges += i[1]
    average_degree = sum_edges/pop_size
    dict = iterations[tmax-1]
    total_R = dict['node_count'][2]
    R_list_erdos.append(total_R)
    k_avg_erdos.append(average_degree)

# Make plot
plt.figure()
plt.xlabel('<k>', fontsize=15)
plt.ylabel('# of people recovered', fontsize=15)
plt.plot(k_avg_erdos, R_list_erdos, label='R')
plt.legend()
# plt.savefig("figs/Recovered_erdos", dpi=400)
plt.show()

# %%
"""

"""
# Set base variables
mlist = np.arange(2,50,1)
R_list_barabasi = []
k_avg_barabasi = []
pop_size = 2500
tmax = 1000

# 
for m in mlist:
    g, iterations = barabasi(pop_size, m, tmax, 'nope')
    degrees = g.degree()
    sum_edges = 0
    for i in degrees:
        sum_edges += i[1]
    average_degree = sum_edges/pop_size
    dict = iterations[tmax-1]
    total_R = dict['node_count'][2]
    R_list_barabasi.append(total_R)
    k_avg_barabasi.append(average_degree)

# Make plot
plt.figure()
plt.xlabel('<k>', fontsize=15)
plt.ylabel('# of people recovered', fontsize=15)
plt.plot(k_avg_barabasi, R_list_barabasi, label='R')
plt.legend()
# plt.savefig("figs/Recovered_barabasi", dpi=400)
plt.show()

# %%
"""

"""
# Set base variables
k_initial = np.arange(5, 65, 1)
R_list_watts = []
k_avg_watts = []
pop_size = 2500
tmax = 1000

# 
for k in k_initial:
    g, iterations = watts(pop_size, k, tmax, 'nope')
    degrees = g.degree()
    sum_edges = 0
    for i in degrees:
        sum_edges += i[1]
    average_degree = sum_edges/pop_size
    dict = iterations[tmax-1]
    total_R = dict['node_count'][2]
    R_list_watts.append(total_R)
    k_avg_watts.append(average_degree)

# Make plot
plt.figure()
plt.xlabel('<k>', fontsize=15)
plt.ylabel('# of people recovered', fontsize=15)
plt.plot(k_avg_watts, R_list_watts, label='R')
plt.legend()
# plt.savefig("figs/Recovered_watts", dpi=400)
plt.show()

# %%
# Plot multiple
plt.figure()
plt.xlabel('<k>', fontsize=15)
plt.ylabel('# of people recovered', fontsize=15)
plt.plot(k_avg_watts, R_list_watts, label='R watts')
plt.plot(k_avg_erdos, R_list_erdos, label='R erdos')
plt.plot(k_avg_barabasi, R_list_barabasi, label='R bar.')
# plt.savefig("figs/Recovered_all", dpi=400)
plt.legend()
plt.show()

# %% [markdown]
# ### Vary Disease Initalisation

# %%
p = 0.01
i = [[], [], [], []]
irand = [[], [], [], []]
pop_size = 2500
tmax = 1250

for t in np.arange(0, 4):
    ghub, iterationshub = erdos(pop_size, p, tmax, 'hub')
    grandom, iterationsrandom = erdos(pop_size, p, tmax, 'random')
    for j in np.arange(0, tmax):
        dicthub = iterationshub[j]
        i[t].append(dicthub['node_count'][1])
        dictrandom = iterationsrandom[j]
        irand[t].append(dictrandom['node_count'][1])


# Create subplot
f, ax = plt.subplots(2,2)
index = 0
for row in ax:
    for col in row:
        # Plot deterministic
        col.plot(i[index])
        # Plot stochastic
        col.plot(irand[index])
        if index < 2:
            col.tick_params(axis='x', which='both', labelbottom=False)
        if index % 2 != 0:
            col.tick_params(axis='y', which='both', labelleft=False)

        index += 1

f.text(0.03, 0.5, 'number of people', va='center', rotation='vertical', fontsize=15)
f.text(0.5, 0.03, 'iteration', ha='center', fontsize=15)
plt.subplots_adjust(wspace=0.05, hspace=0.1)
# plt.savefig("figs/Initalization_erdos_stoch001", dpi=400)
plt.show()

# %%
p = 0.1
i = [[], [], [], []]
irand = [[], [], [], []]
pop_size = 2500
tmax = 500

for t in np.arange(0, 4):
    ghub, iterationshub = erdos(pop_size, p, tmax, 'hub')
    grandom, iterationsrandom = erdos(pop_size, p, tmax, 'random')
    for j in np.arange(0, tmax):
        dicthub = iterationshub[j]
        i[t].append(dicthub['node_count'][1])
        dictrandom = iterationsrandom[j]
        irand[t].append(dictrandom['node_count'][1])


# Create subplot
f, ax = plt.subplots(2,2)
index = 0
for row in ax:
    for col in row:
        # Plot deterministic
        col.plot(i[index])
        # Plot stochastic
        col.plot(irand[index])
        if index < 2:
            col.tick_params(axis='x', which='both', labelbottom=False)
        if index % 2 != 0:
            col.tick_params(axis='y', which='both', labelleft=False)

        index += 1

f.text(0.02, 0.5, 'number of people', va='center', rotation='vertical', fontsize=15)
f.text(0.5, 0.02, 'iteration', ha='center', fontsize=15)
plt.subplots_adjust(wspace=0.05, hspace=0.1)
# plt.savefig("figs/Initalization_erdos_stoch", dpi=400)
plt.show()

# %%
k = 50
i = [[], [], [], []]
irand = [[], [], [], []]
pop_size = 2500
tmax = 750

for t in np.arange(0, 4):
    ghub, iterationshub = watts(pop_size, k, tmax, 'hub')
    grandom, iterationsrandom = watts(pop_size, k, tmax, 'random')
    for j in np.arange(0, tmax):
        dicthub = iterationshub[j]
        i[t].append(dicthub['node_count'][1])
        dictrandom = iterationsrandom[j]
        irand[t].append(dictrandom['node_count'][1])


# Create subplot
f, ax = plt.subplots(2,2)
index = 0
for row in ax:
    for col in row:
        # Plot deterministic
        col.plot(i[index])
        # Plot stochastic
        col.plot(irand[index])
        if index < 2:
            col.tick_params(axis='x', which='both', labelbottom=False)
        if index % 2 != 0:
            col.tick_params(axis='y', which='both', labelleft=False)

        index += 1

f.text(0.03, 0.5, 'number of people', va='center', rotation='vertical', fontsize=15)
f.text(0.5, 0.03, 'iteration', ha='center', fontsize=15)
plt.subplots_adjust(wspace=0.05, hspace=0.1)
# plt.savefig("figs/Initalization_watts_stoch", dpi=400)
plt.show()

# %%
m = 20
i = [[], [], [], []]
irand = [[], [], [], []]
pop_size = 2500
tmax = 1000

for t in np.arange(0, 4):
    ghub, iterationshub = barabasi(pop_size, m, tmax, 'hub')
    grandom, iterationsrandom =  barabasi(pop_size, m, tmax, 'random')
    for j in np.arange(0, tmax):
        dicthub = iterationshub[j]
        i[t].append(dicthub['node_count'][1])
        dictrandom = iterationsrandom[j]
        irand[t].append(dictrandom['node_count'][1])


# Create subplot
f, ax = plt.subplots(2,2)
index = 0
for row in ax:
    for col in row:
        # Plot deterministic
        col.plot(i[index])
        # Plot stochastic
        col.plot(irand[index])
        if index < 2:
            col.tick_params(axis='x', which='both', labelbottom=False)
        if index % 2 != 0:
            col.tick_params(axis='y', which='both', labelleft=False)

        index += 1

f.text(0.03, 0.5, 'number of people', va='center', rotation='vertical', fontsize=15)
f.text(0.5, 0.03, 'iteration', ha='center', fontsize=15)
plt.subplots_adjust(wspace=0.05, hspace=0.1)
# plt.savefig("figs/Initalization_barabasi_stoch", dpi=400)
plt.show()

# %% [markdown]
# ### Vaccination Strategies

# %%
p = 0.01
i = [[], [], [], []]
irand = [[], [], [], []]
pop_size = 2500
tmax = 500

for t in np.arange(0, 4):
    ghub, infhub = erdos(pop_size, p, tmax, 'vaccinhub')
    grandom, infrandom = erdos(pop_size, p, tmax, 'vaccinrandom')
    for j in np.arange(0, tmax):
        i[t].append(infhub[j])
        irand[t].append(infrandom[j])


# Create subplot
f, ax = plt.subplots(2,2)
index = 0
for row in ax:
    for col in row:
        # Plot deterministic
        col.plot(i[index])
        # Plot stochastic
        col.plot(irand[index])
        if index < 2:
            col.tick_params(axis='x', which='both', labelbottom=False)
        if index % 2 != 0:
            col.tick_params(axis='y', which='both', labelleft=False)

        index += 1

f.text(0.03, 0.5, 'number of people', va='center', rotation='vertical', fontsize=15)
f.text(0.5, 0.03, 'iteration', ha='center', fontsize=15)
plt.subplots_adjust(wspace=0.05, hspace=0.1)
# plt.savefig("figs/Vaccination_erdos_stoch_p=001", dpi=400)
plt.show()

# %%
p = 0.1
i = [[], [], [], []]
irand = [[], [], [], []]
pop_size = 2500
tmax = 500

for t in np.arange(0, 4):
    ghub, infhub = erdos(pop_size, p, tmax, 'vaccinhub')
    grandom, infrandom = erdos(pop_size, p, tmax, 'vaccinrandom')
    for j in np.arange(0, tmax):
        i[t].append(infhub[j])
        irand[t].append(infrandom[j])


# Create subplot
f, ax = plt.subplots(2,2)
index = 0
for row in ax:
    for col in row:
        # Plot deterministic
        col.plot(i[index])
        # Plot stochastic
        col.plot(irand[index])
        if index < 2:
            col.tick_params(axis='x', which='both', labelbottom=False)
        if index % 2 != 0:
            col.tick_params(axis='y', which='both', labelleft=False)

        index += 1

f.text(0.02, 0.5, 'number of people', va='center', rotation='vertical', fontsize=15)
f.text(0.5, 0.02, 'iteration', ha='center', fontsize=15)
plt.subplots_adjust(wspace=0.05, hspace=0.1)
# plt.savefig("figs/Vaccination_erdos_stoch_p=01", dpi=400)
plt.show()

# %%
k = 50
i = [[], [], [], []]
irand = [[], [], [], []]
pop_size = 2500
tmax = 750

for t in np.arange(0, 4):
    ghub, infhub = watts(pop_size, k, tmax, 'vaccinhub')
    grandom, infrandom = watts(pop_size, k, tmax, 'vaccinrandom')
    for j in np.arange(0, tmax):
        i[t].append(infhub[j])
        irand[t].append(infrandom[j])


# Create subplot
f, ax = plt.subplots(2,2)
index = 0
for row in ax:
    for col in row:
        # Plot deterministic
        col.plot(i[index])
        # Plot stochastic
        col.plot(irand[index])
        if index < 2:
            col.tick_params(axis='x', which='both', labelbottom=False)
        if index % 2 != 0:
            col.tick_params(axis='y', which='both', labelleft=False)

        index += 1

f.text(0.03, 0.5, 'number of people', va='center', rotation='vertical', fontsize=15)
f.text(0.5, 0.03, 'iteration', ha='center', fontsize=15)
plt.subplots_adjust(wspace=0.05, hspace=0.1)
# plt.savefig("figs/Vaccination_watts_stoch", dpi=400)
plt.show()

# %%
m = 20
i = [[], [], [], []]
irand = [[], [], [], []]
pop_size = 2500
tmax = 750

for t in np.arange(0, 4):
    ghub, infhub = barabasi(pop_size, m, tmax, 'vaccinhub')
    grandom, infrandom = barabasi(pop_size, m, tmax, 'vaccinrandom')
    for j in np.arange(0, tmax):
        i[t].append(infhub[j])
        irand[t].append(infrandom[j])


# Create subplot
f, ax = plt.subplots(2,2)
index = 0
for row in ax:
    for col in row:
        # Plot deterministic
        col.plot(i[index])
        # Plot stochastic
        col.plot(irand[index])
        if index < 2:
            col.tick_params(axis='x', which='both', labelbottom=False)
        if index % 2 != 0:
            col.tick_params(axis='y', which='both', labelleft=False)

        index += 1

f.text(0.03, 0.5, 'number of people', va='center', rotation='vertical', fontsize=15)
f.text(0.5, 0.03, 'iteration', ha='center', fontsize=15)
plt.subplots_adjust(wspace=0.05, hspace=0.1)
# plt.savefig("figs/Vaccination_barabasi_stoch", dpi=400)
plt.show()
